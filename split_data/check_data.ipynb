# %% [markdown]
# # Init Data

# %%
import os
import json
import pandas as pd


NODE_FILE = "/playpen/jesse/drug_repurpose/PrimeKG/nodes.csv"
df_node = pd.read_csv(NODE_FILE)

unique_node_types = df_node['node_type'].nunique()
print(f"Number of unique node types: {unique_node_types}")

print("Unique node types:")
print(df_node['node_type'].unique())

print("\nCount of each node type:")
print(df_node['node_type'].value_counts())

df_node
# Out:
# Number of unique node types: 10
# Unique node types:
# ['gene/protein' 'drug' 'effect/phenotype' 'disease' 'biological_process'
#  'molecular_function' 'cellular_component' 'exposure' 'pathway' 'anatomy']
#
# Count of each node type:
# node_type
# biological_process    28642
# gene/protein          27671
# disease               17080
# effect/phenotype      15311
# anatomy               14035
# molecular_function    11169
# drug                   7957
# cellular_component     4176
# pathway                2516
# exposure                818
# Name: count, dtype: int64
#         node_index       node_id     node_type  \
# 0                0          9796  gene/protein
# 1                1          7918  gene/protein
# 2                2          8233  gene/protein
# 3                3          4899  gene/protein
# 4                4          5297  gene/protein
# ...            ...           ...           ...
# 129370      129370  R-HSA-936837       pathway
# 129371      129371  R-HSA-997272       pathway
# 129372      129372          1062       anatomy
# 129373      129373           468       anatomy
# 129374      129374           992       anatomy
#
#                                                 node_name node_source
# 0                                                  PHYHIP        NCBI
# 1                                                  GPANK1        NCBI
# 2                                                   ZRSR2        NCBI
# 3                                                    NRF1        NCBI
# 4                                                   PI4KA        NCBI
# ...                                                   ...         ...
# 129370                    Ion transport by P-type ATPases    REACTOME
# 129371  Inhibition  of voltage gated Ca2+ channels via...    REACTOME
# 129372                                  anatomical entity      UBERON
# 129373                            multi-cellular organism      UBERON
# 129374                                       female gonad      UBERON
#
# [129375 rows x 5 columns]

# %%
EDGE_FILE = "/playpen/jesse/drug_repurpose/PrimeKG/edges.csv"  
df_edges = pd.read_csv(EDGE_FILE)

unique_relations = df_edges['relation'].nunique()
print(f"Number of unique relation types: {unique_relations}")

print("\nUnique relation types:")
print(df_edges['relation'].unique())

print("\nRelation counts:")
print(df_edges['relation'].value_counts())
# Out:
# Number of unique relation types: 30
#
# Unique relation types:
# ['protein_protein' 'drug_protein' 'contraindication' 'indication'
#  'off-label use' 'drug_drug' 'phenotype_protein' 'phenotype_phenotype'
#  'disease_phenotype_negative' 'disease_phenotype_positive'
#  'disease_protein' 'disease_disease' 'drug_effect' 'bioprocess_bioprocess'
#  'molfunc_molfunc' 'cellcomp_cellcomp' 'molfunc_protein'
#  'cellcomp_protein' 'bioprocess_protein' 'exposure_protein'
#  'exposure_disease' 'exposure_exposure' 'exposure_bioprocess'
#  'exposure_molfunc' 'exposure_cellcomp' 'pathway_pathway'
#  'pathway_protein' 'anatomy_anatomy' 'anatomy_protein_present'
#  'anatomy_protein_absent']
#
# Relation counts:
# relation
# anatomy_protein_present       3036406
# drug_drug                     2672628
# protein_protein                642150
# disease_phenotype_positive     300634
# bioprocess_protein             289610
# cellcomp_protein               166804
# disease_protein                160822
# molfunc_protein                139060
# drug_effect                    129568
# bioprocess_bioprocess          105772
# pathway_protein                 85292
# disease_disease                 64388
# contraindication                61350
# drug_protein                    51306
# anatomy_protein_absent          39774
# phenotype_phenotype             37472
# anatomy_anatomy                 28064
# molfunc_molfunc                 27148
# indication                      18776
# cellcomp_cellcomp                9690
# phenotype_protein                6660
# off-label use                    5136
# pathway_pathway                  5070
# exposure_disease                 4608
# exposure_exposure                4140
# exposure_bioprocess              3250
# exposure_protein                 2424
# disease_phenotype_negative       2386
# exposure_molfunc                   90
# exposure_cellcomp                  20
# Name: count, dtype: int64

# %%
print(df_edges)
# Out:
#                        relation   display_relation  x_index  y_index
# 0               protein_protein                ppi        0     8889
# 1               protein_protein                ppi        1     2798
# 2               protein_protein                ppi        2     5646
# 3               protein_protein                ppi        3    11592
# 4               protein_protein                ppi        4     2122
# ...                         ...                ...      ...      ...
# 8100493  anatomy_protein_absent  expression absent    66747     5259
# 8100494  anatomy_protein_absent  expression absent    63824    58254
# 8100495  anatomy_protein_absent  expression absent    63826    58254
# 8100496  anatomy_protein_absent  expression absent    64523    58254
# 8100497  anatomy_protein_absent  expression absent    67302    58254
#
# [8100498 rows x 4 columns]

# %% [markdown]
# # Step1: Test data check and combination

# %%
test_postive = pd.read_csv("/playpen/jesse/drug_repurpose/split_data/data_analysis/test_positive_full.csv")
print(test_postive)
# Out:
#      drug_index  disease_index drug_type           drug_name disease_type  \
# 0         14520          33651      drug           Allantoin      disease
# 1         15098          33683      drug           Promazine      disease
# 2         15493          29637      drug       Bromocriptine      disease
# 3         14275          30654      drug         Doxorubicin      disease
# 4         20375          33714      drug  Aluminum hydroxide      disease
# ..          ...            ...       ...                 ...          ...
# 495       15778          28208      drug          Tolazamide      disease
# 496       15179          33703      drug        Nicotinamide      disease
# 497       14269          32531      drug  Methylprednisolone      disease
# 498       15451          33577      drug          Bisoprolol      disease
# 499       14196          28851      drug         Propranolol      disease
#
#                                   disease_name  \
# 0                        seborrheic dermatitis
# 1                          urticaria (disease)
# 2    prolactin producing pituitary gland tumor
# 3     acute lymphoblastic/lymphocytic leukemia
# 4                        esophagitis (disease)
# ..                                         ...
# 495                   type 2 diabetes mellitus
# 496                             acne (disease)
# 497                       mantle cell lymphoma
# 498                      hypertensive disorder
# 499                  Kasabach-Merritt syndrome
#
#                                     related_phenotypes  \
# 0                                       [94334, 22550]
# 1                  [94533, 22540, 25518, 94454, 94520]
# 2    [25479, 84488, 90495, 25620, 25599, 84764, 225...
# 3                         [23970, 86308, 22757, 84890]
# 4                         [93737, 22987, 22988, 94534]
# ..                                                 ...
# 495                [22759, 24491, 22483, 91382, 85559]
# 496                       [22539, 94372, 94243, 94244]
# 497  [22952, 25547, 23214, 24143, 85040, 24337, 256...
# 498                       [23513, 94180, 22741, 94390]
# 499  [22791, 87306, 85009, 22933, 22934, 86296, 225...
#
#                                       related_proteins
# 0                                          [1641, 150]
# 1    [3552, 417, 8834, 5667, 4968, 2889, 7083, 1004...
# 2    [3104, 2401, 2789, 3046, 1884, 22023, 5320, 10...
# 3    [2, 9221, 1549, 4111, 13840, 4114, 1558, 1559,...
# 4         [2978, 9029, 4425, 12842, 1740, 12766, 4959]
# ..                                                 ...
# 495  [34295, 13830, 7688, 10248, 34312, 34317, 3431...
# 496                          [12305, 1587, 6229, 1485]
# 497  [769, 134, 6926, 4369, 7186, 7441, 8212, 1558,...
# 498  [8805, 3912, 11080, 2667, 33776, 4497, 22002, ...
# 499                            [2840, 177, 7212, 9965]
#
# [500 rows x 8 columns]

# %%
test_postive_new = pd.read_csv("/playpen/jesse/drug_repurpose/split_data/data_analysis/test_positive_full_new.csv")
print(test_postive_new)
# Out:
#      drug_index  disease_index drug_type           drug_name disease_type  \
# 0         14520          33651      drug           Allantoin      disease
# 1         15098          33683      drug           Promazine      disease
# 2         15493          29637      drug       Bromocriptine      disease
# 3         14275          30654      drug         Doxorubicin      disease
# 4         20375          33714      drug  Aluminum hydroxide      disease
# ..          ...            ...       ...                 ...          ...
# 496       15179          33703      drug        Nicotinamide      disease
# 497       14269          32531      drug  Methylprednisolone      disease
# 498       15451          33577      drug          Bisoprolol      disease
# 499       14196          28851      drug         Propranolol      disease
# 500       15098          37888      drug           Promazine      disease
#
#                                   disease_name  \
# 0                        seborrheic dermatitis
# 1                          urticaria (disease)
# 2    prolactin producing pituitary gland tumor
# 3     acute lymphoblastic/lymphocytic leukemia
# 4                        esophagitis (disease)
# ..                                         ...
# 496                             acne (disease)
# 497                       mantle cell lymphoma
# 498                      hypertensive disorder
# 499                  Kasabach-Merritt syndrome
# 500                          allergic rhinitis
#
#                                     related_phenotypes  \
# 0                                       [94334, 22550]
# 1                  [94533, 22540, 25518, 94454, 94520]
# 2    [25479, 84488, 90495, 25620, 25599, 84764, 225...
# 3                         [23970, 86308, 22757, 84890]
# 4                         [93737, 22987, 22988, 94534]
# ..                                                 ...
# 496                       [22539, 94372, 94243, 94244]
# 497  [22952, 25547, 23214, 24143, 85040, 24337, 256...
# 498                       [23513, 94180, 22741, 94390]
# 499  [22791, 87306, 85009, 22933, 22934, 86296, 225...
# 500                                     [25610, 23083]
#
#                                       related_proteins
# 0                                          [1641, 150]
# 1    [3552, 417, 8834, 5667, 4968, 2889, 7083, 1004...
# 2    [3104, 2401, 2789, 3046, 1884, 22023, 5320, 10...
# 3    [2, 9221, 1549, 4111, 13840, 4114, 1558, 1559,...
# 4         [2978, 9029, 4425, 12842, 1740, 12766, 4959]
# ..                                                 ...
# 496                          [12305, 1587, 6229, 1485]
# 497  [769, 134, 6926, 4369, 7186, 7441, 8212, 1558,...
# 498  [8805, 3912, 11080, 2667, 33776, 4497, 22002, ...
# 499                            [2840, 177, 7212, 9965]
# 500                           [8354, 3451, 3818, 4315]
#
# [501 rows x 8 columns]

# %%
diff_new = test_postive_new.merge(test_postive, how='outer', indicator=True).query('_merge == "left_only"')
print("Rows only in new DF:")
print(diff_new)
# Out:
# Rows only in new DF:
#      drug_index  disease_index drug_type  drug_name disease_type  \
# 238       15098          37888      drug  Promazine      disease
#
#           disease_name related_phenotypes          related_proteins     _merge
# 238  allergic rhinitis     [25610, 23083]  [8354, 3451, 3818, 4315]  left_only

# %%
test_positive_gd = pd.merge(
    test_postive,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
 

test_positive_gd = test_positive_gd[test_positive_gd['relation'] == 'indication']
# test_positive_gd.to_csv('./data_analysis/test_positive_gd.csv', index=False) 
test_positive_gd
# Out:
#      drug_index  disease_index drug_type           drug_name disease_type  \
# 0         14520          33651      drug           Allantoin      disease
# 2         15098          33683      drug           Promazine      disease
# 3         15493          29637      drug       Bromocriptine      disease
# 4         14275          30654      drug         Doxorubicin      disease
# 6         20375          33714      drug  Aluminum hydroxide      disease
# ..          ...            ...       ...                 ...          ...
# 504       15778          28208      drug          Tolazamide      disease
# 505       15179          33703      drug        Nicotinamide      disease
# 506       14269          32531      drug  Methylprednisolone      disease
# 507       15451          33577      drug          Bisoprolol      disease
# 508       14196          28851      drug         Propranolol      disease
#
#                                   disease_name  \
# 0                        seborrheic dermatitis
# 2                          urticaria (disease)
# 3    prolactin producing pituitary gland tumor
# 4     acute lymphoblastic/lymphocytic leukemia
# 6                        esophagitis (disease)
# ..                                         ...
# 504                   type 2 diabetes mellitus
# 505                             acne (disease)
# 506                       mantle cell lymphoma
# 507                      hypertensive disorder
# 508                  Kasabach-Merritt syndrome
#
#                                     related_phenotypes  \
# 0                                       [94334, 22550]
# 2                  [94533, 22540, 25518, 94454, 94520]
# 3    [25479, 84488, 90495, 25620, 25599, 84764, 225...
# 4                         [23970, 86308, 22757, 84890]
# 6                         [93737, 22987, 22988, 94534]
# ..                                                 ...
# 504                [22759, 24491, 22483, 91382, 85559]
# 505                       [22539, 94372, 94243, 94244]
# 506  [22952, 25547, 23214, 24143, 85040, 24337, 256...
# 507                       [23513, 94180, 22741, 94390]
# 508  [22791, 87306, 85009, 22933, 22934, 86296, 225...
#
#                                       related_proteins    relation  \
# 0                                          [1641, 150]  indication
# 2    [3552, 417, 8834, 5667, 4968, 2889, 7083, 1004...  indication
# 3    [3104, 2401, 2789, 3046, 1884, 22023, 5320, 10...  indication
# 4    [2, 9221, 1549, 4111, 13840, 4114, 1558, 1559,...  indication
# 6         [2978, 9029, 4425, 12842, 1740, 12766, 4959]  indication
# ..                                                 ...         ...
# 504  [34295, 13830, 7688, 10248, 34312, 34317, 3431...  indication
# 505                          [12305, 1587, 6229, 1485]  indication
# 506  [769, 134, 6926, 4369, 7186, 7441, 8212, 1558,...  indication
# 507  [8805, 3912, 11080, 2667, 33776, 4497, 22002, ...  indication
# 508                            [2840, 177, 7212, 9965]  indication
#
#     display_relation  x_index  y_index
# 0         indication    14520    33651
# 2         indication    15098    33683
# 3         indication    15493    29637
# 4         indication    14275    30654
# 6         indication    20375    33714
# ..               ...      ...      ...
# 504       indication    15778    28208
# 505       indication    15179    33703
# 506       indication    14269    32531
# 507       indication    15451    33577
# 508       indication    14196    28851
#
# [500 rows x 12 columns]

# %%
test_positive_gd_new = pd.merge(
    test_postive_new,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
 

test_positive_gd_new = test_positive_gd_new[test_positive_gd_new['relation'] == 'indication']
test_positive_gd_new.to_csv('./data_analysis/test_positive_gd_new.csv', index=False) 
test_positive_gd_new
# Out:
#      drug_index  disease_index drug_type           drug_name disease_type  \
# 0         14520          33651      drug           Allantoin      disease
# 2         15098          33683      drug           Promazine      disease
# 3         15493          29637      drug       Bromocriptine      disease
# 4         14275          30654      drug         Doxorubicin      disease
# 6         20375          33714      drug  Aluminum hydroxide      disease
# ..          ...            ...       ...                 ...          ...
# 505       15179          33703      drug        Nicotinamide      disease
# 506       14269          32531      drug  Methylprednisolone      disease
# 507       15451          33577      drug          Bisoprolol      disease
# 508       14196          28851      drug         Propranolol      disease
# 509       15098          37888      drug           Promazine      disease
#
#                                   disease_name  \
# 0                        seborrheic dermatitis
# 2                          urticaria (disease)
# 3    prolactin producing pituitary gland tumor
# 4     acute lymphoblastic/lymphocytic leukemia
# 6                        esophagitis (disease)
# ..                                         ...
# 505                             acne (disease)
# 506                       mantle cell lymphoma
# 507                      hypertensive disorder
# 508                  Kasabach-Merritt syndrome
# 509                          allergic rhinitis
#
#                                     related_phenotypes  \
# 0                                       [94334, 22550]
# 2                  [94533, 22540, 25518, 94454, 94520]
# 3    [25479, 84488, 90495, 25620, 25599, 84764, 225...
# 4                         [23970, 86308, 22757, 84890]
# 6                         [93737, 22987, 22988, 94534]
# ..                                                 ...
# 505                       [22539, 94372, 94243, 94244]
# 506  [22952, 25547, 23214, 24143, 85040, 24337, 256...
# 507                       [23513, 94180, 22741, 94390]
# 508  [22791, 87306, 85009, 22933, 22934, 86296, 225...
# 509                                     [25610, 23083]
#
#                                       related_proteins    relation  \
# 0                                          [1641, 150]  indication
# 2    [3552, 417, 8834, 5667, 4968, 2889, 7083, 1004...  indication
# 3    [3104, 2401, 2789, 3046, 1884, 22023, 5320, 10...  indication
# 4    [2, 9221, 1549, 4111, 13840, 4114, 1558, 1559,...  indication
# 6         [2978, 9029, 4425, 12842, 1740, 12766, 4959]  indication
# ..                                                 ...         ...
# 505                          [12305, 1587, 6229, 1485]  indication
# 506  [769, 134, 6926, 4369, 7186, 7441, 8212, 1558,...  indication
# 507  [8805, 3912, 11080, 2667, 33776, 4497, 22002, ...  indication
# 508                            [2840, 177, 7212, 9965]  indication
# 509                           [8354, 3451, 3818, 4315]  indication
#
#     display_relation  x_index  y_index
# 0         indication    14520    33651
# 2         indication    15098    33683
# 3         indication    15493    29637
# 4         indication    14275    30654
# 6         indication    20375    33714
# ..               ...      ...      ...
# 505       indication    15179    33703
# 506       indication    14269    32531
# 507       indication    15451    33577
# 508       indication    14196    28851
# 509       indication    15098    37888
#
# [501 rows x 12 columns]

# %%
test_negative = pd.read_csv("/playpen/jesse/drug_repurpose/split_data/data_analysis/test_negative_full.csv")
print(test_negative)

test_negative_new = pd.read_csv("/playpen/jesse/drug_repurpose/split_data/data_analysis/test_negative_full_new.csv")
print(test_negative_new)
# Out:
#      drug_index  disease_index drug_type            drug_name disease_type  \
# 0         20391          28811      drug  Silver sulfadiazine      disease
# 1         15294          28547      drug              Tacrine      disease
# 2         14783          33679      drug             Caffeine      disease
# 3         20239          29188      drug        Penicillamine      disease
# 4         17243          27326      drug          Alimemazine      disease
# ..          ...            ...       ...                  ...          ...
# 495       15542          28456      drug          Milnacipran      disease
# 496       15584          31790      drug           Lanreotide      disease
# 497       14168          31493      drug       Spironolactone      disease
# 498       20427          31918      drug       Cholestyramine      disease
# 499       20350          30491      drug      Pentaerithrityl      disease
#
#                                           disease_name  \
# 0                                           cystinuria
# 1                                    Parkinson disease
# 2                         potassium deficiency disease
# 3    autosomal recessive severe congenital neutrope...
# 4                                     long QT syndrome
# ..                                                 ...
# 495  nephrogenic syndrome of inappropriate antidiur...
# 496                                     cholelithiasis
# 497                                       pancreatitis
# 498                                    phenylketonuria
# 499                   obstructive sleep apnea syndrome
#
#                                     related_phenotypes  \
# 0    [25699, 26180, 22759, 22472, 85642, 85419, 850...
# 1    [25858, 84357, 24327, 25224, 24331, 23564, 226...
# 2                                       [94408, 23033]
# 3                                [22124, 22933, 26180]
# 4    [89225, 94223, 26257, 84369, 94225, 84887, 238...
# ..                                                 ...
# 495  [84363, 89132, 85457, 84885, 27094, 23000, 894...
# 496                                     [25522, 88486]
# 497  [24224, 87330, 26180, 22759, 86573, 23950, 861...
# 498  [88450, 85125, 22277, 84616, 22156, 24462, 245...
# 499                       [26449, 84853, 25854, 22759]
#
#                                       related_proteins
# 0    [7457, 12289, 5829, 7302, 13706, 34890, 10413,...
# 1    [8192, 22017, 519, 11, 8212, 9237, 1567, 6175,...
# 2             [1760, 8805, 12165, 172, 213, 1494, 509]
# 3                       [6671, 6002, 1908, 8733, 3231]
# 4    [7177, 9233, 34962, 7198, 1968, 177, 10417, 35...
# ..                                                 ...
# 495                                             [7937]
# 496                              [13976, 22077, 13230]
# 497  [12165, 33925, 33926, 10376, 33929, 2698, 3405...
# 498                                      [9905, 10181]
# 499                                  [5203, 341, 9207]
#
# [500 rows x 8 columns]
#      drug_index  disease_index drug_type            drug_name disease_type  \
# 0         20391          28811      drug  Silver sulfadiazine      disease
# 1         15294          28547      drug              Tacrine      disease
# 2         14783          33679      drug             Caffeine      disease
# 3         20239          29188      drug        Penicillamine      disease
# 4         17243          27326      drug          Alimemazine      disease
# ..          ...            ...       ...                  ...          ...
# 497       14168          31493      drug       Spironolactone      disease
# 498       20427          31918      drug       Cholestyramine      disease
# 499       20350          30491      drug      Pentaerithrityl      disease
# 500       15776          27933      drug             Nabilone      disease
# 501       15075          31790      drug           Cevimeline      disease
#
#                                           disease_name  \
# 0                                           cystinuria
# 1                                    Parkinson disease
# 2                         potassium deficiency disease
# 3    autosomal recessive severe congenital neutrope...
# 4                                     long QT syndrome
# ..                                                 ...
# 497                                       pancreatitis
# 498                                    phenylketonuria
# 499                   obstructive sleep apnea syndrome
# 500                                   anxiety disorder
# 501                                     cholelithiasis
#
#                                     related_phenotypes  \
# 0    [25699, 26180, 22759, 22472, 85642, 85419, 850...
# 1    [25858, 84357, 24327, 25224, 24331, 23564, 226...
# 2                                       [94408, 23033]
# 3                                [22124, 22933, 26180]
# 4    [89225, 94223, 26257, 84369, 94225, 84887, 238...
# ..                                                 ...
# 497  [24224, 87330, 26180, 22759, 86573, 23950, 861...
# 498  [88450, 85125, 22277, 84616, 22156, 24462, 245...
# 499                       [26449, 84853, 25854, 22759]
# 500                                     [22759, 22447]
# 501                                     [25522, 88486]
#
#                                       related_proteins
# 0    [7457, 12289, 5829, 7302, 13706, 34890, 10413,...
# 1    [8192, 22017, 519, 11, 8212, 9237, 1567, 6175,...
# 2             [1760, 8805, 12165, 172, 213, 1494, 509]
# 3                       [6671, 6002, 1908, 8733, 3231]
# 4    [7177, 9233, 34962, 7198, 1968, 177, 10417, 35...
# ..                                                 ...
# 497  [12165, 33925, 33926, 10376, 33929, 2698, 3405...
# 498                                      [9905, 10181]
# 499                                  [5203, 341, 9207]
# 500  [8192, 10257, 22, 6175, 33, 2082, 2096, 6195, ...
# 501                              [13976, 22077, 13230]
#
# [502 rows x 8 columns]

# %%
test_negative_gd = pd.merge(
    test_negative,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
test_negative_gd = test_negative_gd[test_negative_gd['relation'] == 'contraindication']
# test_negative_gd.to_csv('./data_analysis/test_negative_gd.csv', index=False)  
test_negative_gd


test_negative_gd_new = pd.merge(
    test_negative_new,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
test_negative_gd_new = test_negative_gd_new[test_negative_gd_new['relation'] == 'contraindication']
test_negative_gd_new.to_csv('./data_analysis/test_negative_gd_new.csv', index=False)  
test_negative_gd_new
# Out:
#      drug_index  disease_index drug_type            drug_name disease_type  \
# 0         20391          28811      drug  Silver sulfadiazine      disease
# 1         15294          28547      drug              Tacrine      disease
# 2         14783          33679      drug             Caffeine      disease
# 3         20239          29188      drug        Penicillamine      disease
# 4         17243          27326      drug          Alimemazine      disease
# ..          ...            ...       ...                  ...          ...
# 500       14168          31493      drug       Spironolactone      disease
# 501       20427          31918      drug       Cholestyramine      disease
# 502       20350          30491      drug      Pentaerithrityl      disease
# 503       15776          27933      drug             Nabilone      disease
# 504       15075          31790      drug           Cevimeline      disease
#
#                                           disease_name  \
# 0                                           cystinuria
# 1                                    Parkinson disease
# 2                         potassium deficiency disease
# 3    autosomal recessive severe congenital neutrope...
# 4                                     long QT syndrome
# ..                                                 ...
# 500                                       pancreatitis
# 501                                    phenylketonuria
# 502                   obstructive sleep apnea syndrome
# 503                                   anxiety disorder
# 504                                     cholelithiasis
#
#                                     related_phenotypes  \
# 0    [25699, 26180, 22759, 22472, 85642, 85419, 850...
# 1    [25858, 84357, 24327, 25224, 24331, 23564, 226...
# 2                                       [94408, 23033]
# 3                                [22124, 22933, 26180]
# 4    [89225, 94223, 26257, 84369, 94225, 84887, 238...
# ..                                                 ...
# 500  [24224, 87330, 26180, 22759, 86573, 23950, 861...
# 501  [88450, 85125, 22277, 84616, 22156, 24462, 245...
# 502                       [26449, 84853, 25854, 22759]
# 503                                     [22759, 22447]
# 504                                     [25522, 88486]
#
#                                       related_proteins          relation  \
# 0    [7457, 12289, 5829, 7302, 13706, 34890, 10413,...  contraindication
# 1    [8192, 22017, 519, 11, 8212, 9237, 1567, 6175,...  contraindication
# 2             [1760, 8805, 12165, 172, 213, 1494, 509]  contraindication
# 3                       [6671, 6002, 1908, 8733, 3231]  contraindication
# 4    [7177, 9233, 34962, 7198, 1968, 177, 10417, 35...  contraindication
# ..                                                 ...               ...
# 500  [12165, 33925, 33926, 10376, 33929, 2698, 3405...  contraindication
# 501                                      [9905, 10181]  contraindication
# 502                                  [5203, 341, 9207]  contraindication
# 503  [8192, 10257, 22, 6175, 33, 2082, 2096, 6195, ...  contraindication
# 504                              [13976, 22077, 13230]  contraindication
#
#      display_relation  x_index  y_index
# 0    contraindication    20391    28811
# 1    contraindication    15294    28547
# 2    contraindication    14783    33679
# 3    contraindication    20239    29188
# 4    contraindication    17243    27326
# ..                ...      ...      ...
# 500  contraindication    14168    31493
# 501  contraindication    20427    31918
# 502  contraindication    20350    30491
# 503  contraindication    15776    27933
# 504  contraindication    15075    31790
#
# [502 rows x 12 columns]

# %%
test_data = pd.concat([test_positive_gd, test_negative_gd], ignore_index=True)
# test_data.to_csv('./test_data.csv', index=False)  

test_data_new = pd.concat([test_positive_gd_new, test_negative_gd_new], ignore_index=True)
# test_data_new.to_csv('./data_analysis/test_data_new.csv', index=False)

# %% [markdown]
# Modify the test_data new manually; remove the duplicate row (14559, 33656) due to the conflict in the PrimeKG.

# %%
test_data = pd.read_csv("/playpen/jesse/drug_repurpose/split_data/test_data.csv")
print(test_data)
# Out:
#      drug_index  disease_index drug_type           drug_name disease_type  \
# 0         14520          33651      drug           Allantoin      disease
# 1         15098          33683      drug           Promazine      disease
# 2         15493          29637      drug       Bromocriptine      disease
# 3         14275          30654      drug         Doxorubicin      disease
# 4         20375          33714      drug  Aluminum hydroxide      disease
# ..          ...            ...       ...                 ...          ...
# 995       15584          31790      drug          Lanreotide      disease
# 996       14168          31493      drug      Spironolactone      disease
# 997       20427          31918      drug      Cholestyramine      disease
# 998       20350          30491      drug     Pentaerithrityl      disease
# 999       15776          27933      drug            Nabilone      disease
#
#                                   disease_name  \
# 0                        seborrheic dermatitis
# 1                          urticaria (disease)
# 2    prolactin producing pituitary gland tumor
# 3     acute lymphoblastic/lymphocytic leukemia
# 4                        esophagitis (disease)
# ..                                         ...
# 995                             cholelithiasis
# 996                               pancreatitis
# 997                            phenylketonuria
# 998           obstructive sleep apnea syndrome
# 999                           anxiety disorder
#
#                                     related_phenotypes  \
# 0                                       [94334, 22550]
# 1                  [94533, 22540, 25518, 94454, 94520]
# 2    [25479, 84488, 90495, 25620, 25599, 84764, 225...
# 3                         [23970, 86308, 22757, 84890]
# 4                         [93737, 22987, 22988, 94534]
# ..                                                 ...
# 995                                     [25522, 88486]
# 996  [24224, 87330, 26180, 22759, 86573, 23950, 861...
# 997  [88450, 85125, 22277, 84616, 22156, 24462, 245...
# 998                       [26449, 84853, 25854, 22759]
# 999                                     [22759, 22447]
#
#                                       related_proteins          relation  \
# 0                                          [1641, 150]        indication
# 1    [3552, 417, 8834, 5667, 4968, 2889, 7083, 1004...        indication
# 2    [3104, 2401, 2789, 3046, 1884, 22023, 5320, 10...        indication
# 3    [2, 9221, 1549, 4111, 13840, 4114, 1558, 1559,...        indication
# 4         [2978, 9029, 4425, 12842, 1740, 12766, 4959]        indication
# ..                                                 ...               ...
# 995                              [13976, 22077, 13230]  contraindication
# 996  [12165, 33925, 33926, 10376, 33929, 2698, 3405...  contraindication
# 997                                      [9905, 10181]  contraindication
# 998                                  [5203, 341, 9207]  contraindication
# 999  [8192, 10257, 22, 6175, 33, 2082, 2096, 6195, ...  contraindication
#
#      display_relation  x_index  y_index
# 0          indication    14520    33651
# 1          indication    15098    33683
# 2          indication    15493    29637
# 3          indication    14275    30654
# 4          indication    20375    33714
# ..                ...      ...      ...
# 995  contraindication    15584    31790
# 996  contraindication    14168    31493
# 997  contraindication    20427    31918
# 998  contraindication    20350    30491
# 999  contraindication    15776    27933
#
# [1000 rows x 12 columns]

# %%
dupes = test_data_new.groupby(
    ['drug_index', 'disease_index']
).size().reset_index(name='count')


print(dupes[dupes['count'] > 1])
# Out:
# Empty DataFrame
# Columns: [drug_index, disease_index, count]
# Index: []

# %% [markdown]
# # Step2: Training data check and combination

# %%
train_negative_gene = pd.read_csv("./data_analysis/train_negative_gene.csv")
train_positive_gene = pd.read_csv("./data_analysis/train_positive_protein.csv")
train_negative_phenotype = pd.read_csv("./data_analysis/train_negative_phenotype.csv")
train_positive_phenotype = pd.read_csv("./data_analysis/train_positive_phenotype.csv")

# %%
train_negative_gene
# Out:
#      drug_index  disease_index  gene_index               drug_name drug_type  \
# 0         14198          36187        4497               Clonidine      drug
# 1         15495          37703        1876               Estazolam      drug
# 2         15078          36035       10901                Tramadol      drug
# 3         14806          83760       10047              Entacapone      drug
# 4         14286          27933        2551              Rifampicin      drug
# ..          ...            ...         ...                     ...       ...
# 495       18277          83760        3466           Levetiracetam      drug
# 496       15783          35641        1863               Cyclizine      drug
# 497       15776          37703        2591                Nabilone      drug
# 498       14476          35966        1497  Testosterone cypionate      drug
# 499       14913          28780        8038         Trifluoperazine      drug
#
#                 disease_name disease_type gene_name     gene_type
# 0    coronary artery disease      disease      NOS3  gene/protein
# 1          neurotic disorder      disease     NTRK2  gene/protein
# 2               hypertension      disease    CYP3A5  gene/protein
# 3         dysthymic disorder      disease     OPRK1  gene/protein
# 4           anxiety disorder      disease      PAWR  gene/protein
# ..                       ...          ...       ...           ...
# 495       dysthymic disorder      disease     HTR3A  gene/protein
# 496                 epilepsy      disease      GFAP  gene/protein
# 497        neurotic disorder      disease    SLC6A4  gene/protein
# 498          prostate cancer      disease     GSTP1  gene/protein
# 499        Alzheimer disease      disease      ACHE  gene/protein
#
# [500 rows x 9 columns]

# %%
train_negative_gene_gd = pd.merge(
    train_negative_gene,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
train_negative_gene_gd = train_negative_gene_gd[train_negative_gene_gd['relation'] == 'contraindication']
# train_negative_gene_gd.to_csv('./data_analysis/train_negative_gene_gd.csv', index=False)  
train_negative_gene_gd
# Out:
#      drug_index  disease_index  gene_index               drug_name drug_type  \
# 0         14198          36187        4497               Clonidine      drug
# 1         15495          37703        1876               Estazolam      drug
# 2         15078          36035       10901                Tramadol      drug
# 3         14806          83760       10047              Entacapone      drug
# 4         14286          27933        2551              Rifampicin      drug
# ..          ...            ...         ...                     ...       ...
# 497       18277          83760        3466           Levetiracetam      drug
# 498       15783          35641        1863               Cyclizine      drug
# 499       15776          37703        2591                Nabilone      drug
# 500       14476          35966        1497  Testosterone cypionate      drug
# 501       14913          28780        8038         Trifluoperazine      drug
#
#                 disease_name disease_type gene_name     gene_type  \
# 0    coronary artery disease      disease      NOS3  gene/protein
# 1          neurotic disorder      disease     NTRK2  gene/protein
# 2               hypertension      disease    CYP3A5  gene/protein
# 3         dysthymic disorder      disease     OPRK1  gene/protein
# 4           anxiety disorder      disease      PAWR  gene/protein
# ..                       ...          ...       ...           ...
# 497       dysthymic disorder      disease     HTR3A  gene/protein
# 498                 epilepsy      disease      GFAP  gene/protein
# 499        neurotic disorder      disease    SLC6A4  gene/protein
# 500          prostate cancer      disease     GSTP1  gene/protein
# 501        Alzheimer disease      disease      ACHE  gene/protein
#
#              relation  display_relation  x_index  y_index
# 0    contraindication  contraindication    14198    36187
# 1    contraindication  contraindication    15495    37703
# 2    contraindication  contraindication    15078    36035
# 3    contraindication  contraindication    14806    83760
# 4    contraindication  contraindication    14286    27933
# ..                ...               ...      ...      ...
# 497  contraindication  contraindication    18277    83760
# 498  contraindication  contraindication    15783    35641
# 499  contraindication  contraindication    15776    37703
# 500  contraindication  contraindication    14476    35966
# 501  contraindication  contraindication    14913    28780
#
# [500 rows x 13 columns]

# %%
train_positive_gene_gd = pd.merge(
    train_positive_gene,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
train_positive_gene_gd = train_positive_gene_gd[train_positive_gene_gd['relation'] == 'indication']
train_positive_gene_gd
# Out:
#      gene_index  disease_index  drug_index        drug_name drug_type  \
# 0          7880          27933       15119  Tranylcypromine      drug
# 1         22002          28313       14913  Trifluoperazine      drug
# 2          3955          36634       14945        Sorafenib      drug
# 3          2401          28801       16842      Pramipexole      drug
# 4          4315          83845       17376       Cefotaxime      drug
# ..          ...            ...         ...              ...       ...
# 518        4315          37703       14310          Doxepin      drug
# 519         864          27933       15197        Mianserin      drug
# 520         125          29375       17605        Cetuximab      drug
# 521         337          83868       14411        Ibrutinib      drug
# 522       12431          83841       15209       Vilazodone      drug
#
#                              disease_name disease_type gene_name  \
# 0                        anxiety disorder      disease    CYP2C9
# 1                           schizophrenia      disease      CALY
# 2                            liver cancer      disease    CYP1A2
# 3    juvenile onset Parkinson disease 19A      disease      DRD2
# 4                        viral meningitis      disease       ALB
# ..                                    ...          ...       ...
# 518                     neurotic disorder      disease       ALB
# 519                      anxiety disorder      disease     HTR2C
# 520               squamous cell carcinoma      disease      EGFR
# 521                      Richter syndrome      disease       BTK
# 522                 endogenous depression      disease   CYP2C19
#
#         gene_type    relation display_relation  x_index  y_index
# 0    gene/protein  indication       indication    15119    27933
# 1    gene/protein  indication       indication    14913    28313
# 2    gene/protein  indication       indication    14945    36634
# 3    gene/protein  indication       indication    16842    28801
# 4    gene/protein  indication       indication    17376    83845
# ..            ...         ...              ...      ...      ...
# 518  gene/protein  indication       indication    14310    37703
# 519  gene/protein  indication       indication    15197    27933
# 520  gene/protein  indication       indication    17605    29375
# 521  gene/protein  indication       indication    14411    83868
# 522  gene/protein  indication       indication    15209    83841
#
# [500 rows x 13 columns]

# %%
train_positive_phenotype_gd = pd.merge(
    train_positive_phenotype,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
train_positive_phenotype_gd = train_positive_phenotype_gd[train_positive_phenotype_gd['relation'] == 'indication']
train_positive_phenotype_gd
# Out:
#      drug_index  disease_index  phenotype_index               drug_name  \
# 0         15772          28547            93516               Tolcapone
# 1         20597          33643            24226               Tivozanib
# 2         14042          29078            25620  Hydrocortisone acetate
# 3         15860          32325            93521   Sodium aurothiomalate
# 4         14390          33609            85707            Azapropazone
# ..          ...            ...              ...                     ...
# 500       15333          28547            22679              Rasagiline
# 501       15077          32531            24143              Bortezomib
# 502       20565          27304            22788         Elosulfase alfa
# 503       17042          33688            94467             Ramucirumab
# 504       15326          33314            23544               Ofloxacin
#
#     drug_type                             disease_name disease_type  \
# 0        drug                        Parkinson disease      disease
# 1        drug           renal cell carcinoma (disease)      disease
# 2        drug                     rheumatoid arthritis      disease
# 3        drug            juvenile idiopathic arthritis      disease
# 4        drug                           osteoarthritis      disease
# ..        ...                                      ...          ...
# 500      drug                        Parkinson disease      disease
# 501      drug                     mantle cell lymphoma      disease
# 502      drug                    mucopolysaccharidosis      disease
# 503      drug  non-small cell lung carcinoma (disease)      disease
# 504      drug                            leptospirosis      disease
#
#                    phenotype_name    phenotype_type    relation  \
# 0                     Impulsivity  effect/phenotype  indication
# 1                  Renal neoplasm  effect/phenotype  indication
# 2                         Fatigue  effect/phenotype  indication
# 3     Mediastinal lymphadenopathy  effect/phenotype  indication
# 4     Osteoarthritis of the elbow  effect/phenotype  indication
# ..                            ...               ...         ...
# 500             Sleep disturbance  effect/phenotype  indication
# 501                  Splenomegaly  effect/phenotype  indication
# 502             Failure to thrive  effect/phenotype  indication
# 503  Squamous cell lung carcinoma  effect/phenotype  indication
# 504                       Myalgia  effect/phenotype  indication
#
#     display_relation  x_index  y_index
# 0         indication    15772    28547
# 1         indication    20597    33643
# 2         indication    14042    29078
# 3         indication    15860    32325
# 4         indication    14390    33609
# ..               ...      ...      ...
# 500       indication    15333    28547
# 501       indication    15077    32531
# 502       indication    20565    27304
# 503       indication    17042    33688
# 504       indication    15326    33314
#
# [500 rows x 13 columns]

# %%
train_negative_phenotype_gd = pd.merge(
    train_negative_phenotype,
    df_edges,
    left_on=['drug_index', 'disease_index'],
    right_on=['x_index', 'y_index']
)
train_negative_phenotype_gd = train_negative_phenotype_gd[train_negative_phenotype_gd['relation'] == 'contraindication']
train_negative_phenotype_gd
# Out:
#      drug_index  disease_index  phenotype_index        drug_name drug_type  \
# 0         17064          27626            84771      Meprobamate      drug
# 1         14249          32719            25974  Pseudoephedrine      drug
# 2         14976          31650            84675        Triazolam      drug
# 3         15116          33091            22437       Paroxetine      drug
# 4         14561          31502            24199  Cholecalciferol      drug
# ..          ...            ...              ...              ...       ...
# 497       16071          28158            23157     Isopropamide      drug
# 498       20303          31122            23368      Trolnitrate      drug
# 499       14026          32899            89372     Flumethasone      drug
# 500       14385          32909            24227      Liraglutide      drug
# 501       14838          27677            85642  Succinylcholine      drug
#
#                                          disease_name disease_type  \
# 0                                    thrombocytopenia      disease
# 1                           congenital hypothyroidism      disease
# 2                                   myasthenia gravis      disease
# 3                                  serotonin syndrome      disease
# 4                                      Wilson disease      disease
# ..                                                ...          ...
# 497                        inflammatory bowel disease      disease
# 498                                 phaeochromocytoma      disease
# 499  pituitary deficiency due to Rathke's pouch cysts      disease
# 500                 medullary thyroid gland carcinoma      disease
# 501                        Miyoshi muscular dystrophy      disease
#
#                phenotype_name    phenotype_type          relation  \
# 0                   Petechiae  effect/phenotype  contraindication
# 1                Macroglossia  effect/phenotype  contraindication
# 2                    Diplopia  effect/phenotype  contraindication
# 3                Restlessness  effect/phenotype  contraindication
# 4                Hepatomegaly  effect/phenotype  contraindication
# ..                        ...               ...               ...
# 497                  Vomiting  effect/phenotype  contraindication
# 498               Proteinuria  effect/phenotype  contraindication
# 499  Enlarged pituitary gland  effect/phenotype  contraindication
# 500          Pheochromocytoma  effect/phenotype  contraindication
# 501     Variable expressivity  effect/phenotype  contraindication
#
#      display_relation  x_index  y_index
# 0    contraindication    17064    27626
# 1    contraindication    14249    32719
# 2    contraindication    14976    31650
# 3    contraindication    15116    33091
# 4    contraindication    14561    31502
# ..                ...      ...      ...
# 497  contraindication    16071    28158
# 498  contraindication    20303    31122
# 499  contraindication    14026    32899
# 500  contraindication    14385    32909
# 501  contraindication    14838    27677
#
# [500 rows x 13 columns]

# %%
train_data = pd.concat([train_negative_gene_gd, train_positive_gene_gd, train_negative_phenotype_gd, train_positive_phenotype_gd], ignore_index=True)

train_data.to_csv('./data_analysis/train_data_full.csv', index=False)

# %%
import jsonlines
import pandas as pd

train_path = "./train.jsonl"
with jsonlines.open(train_path, "a") as f_write:
    for index, row in train_data.iterrows():
        line_dict = {}
        line_dict['drug_name'] = row['drug_name']
        line_dict['disease_name'] = row['disease_name']
        question = f"Is {row['disease_name']} an indication for {row['drug_name']}?"
        if pd.notna(row['gene_name']):
            line_dict['gene_name'] = row['gene_name']
            if row['relation'] == 'indication':
                reason = f"The drug {row['drug_name']} acts as a carrier for the gene {row['gene_name']}. The disease {row['disease_name']} is associated with the gene {row['gene_name']}, so the drug {row['drug_name']} can be used to treat {row['disease_name']}."
                prefix = f"Question: {question}\nReasoning: {reason}\nAnswer: YES."
            if row['relation'] == 'contraindication':
                reason = f"The drug {row['drug_name']} cannot act as a carrier for the gene {row['gene_name']}. But the disease {row['disease_name']} is associated with the gene {row['gene_name']}, so the drug {row['drug_name']} cannot be used to treat {row['disease_name']}."
                prefix = f"Question: {question}\nReasoning: {reason}\nAnswer: NO."
            
            line_dict['prompt'] = prefix

        if pd.notna(row['phenotype_name']):
            line_dict['phenotype_name'] = row['phenotype_name']
            if row['relation'] == 'indication':
                reason = f"The disease {row['disease_name']} is characterized by the phenotype {row['phenotype_name']}, indicating that the drug {row['drug_name']} may be effective in treating {row['disease_name']}."
                prefix = f"Question: {question}\nReasoning: {reason}\nAnswer: YES."
            if row['relation'] == 'contraindication':
                reason = f"The disease {row['disease_name']} is characterized by the phenotype {row['phenotype_name']}, indicating that the drug {row['drug_name']} may not be effective in treating {row['disease_name']}."
                prefix = f"Question: {question}\nReasoning: {reason}\nAnswer: NO." 
                
            line_dict['prompt'] = prefix
        
        line_dict['relation'] = row['relation']
        # f_write.write(line_dict)

# %% [markdown]
# # Step3: Get the Remaining data from the train and test for few shot

# %%
test_data = pd.read_csv("/playpen/jesse/drug_repurpose/split_data/data_analysis/test_data_new.csv")
print(test_data)
# Out:
#      drug_index  disease_index drug_type           drug_name disease_type  \
# 0         14520          33651      drug           Allantoin      disease
# 1         15098          33683      drug           Promazine      disease
# 2         15493          29637      drug       Bromocriptine      disease
# 3         14275          30654      drug         Doxorubicin      disease
# 4         20375          33714      drug  Aluminum hydroxide      disease
# ..          ...            ...       ...                 ...          ...
# 995       14168          31493      drug      Spironolactone      disease
# 996       20427          31918      drug      Cholestyramine      disease
# 997       20350          30491      drug     Pentaerithrityl      disease
# 998       15776          27933      drug            Nabilone      disease
# 999       15075          31790      drug          Cevimeline      disease
#
#                                   disease_name  \
# 0                        seborrheic dermatitis
# 1                          urticaria (disease)
# 2    prolactin producing pituitary gland tumor
# 3     acute lymphoblastic/lymphocytic leukemia
# 4                        esophagitis (disease)
# ..                                         ...
# 995                               pancreatitis
# 996                            phenylketonuria
# 997           obstructive sleep apnea syndrome
# 998                           anxiety disorder
# 999                             cholelithiasis
#
#                                     related_phenotypes  \
# 0                                       [94334, 22550]
# 1                  [94533, 22540, 25518, 94454, 94520]
# 2    [25479, 84488, 90495, 25620, 25599, 84764, 225...
# 3                         [23970, 86308, 22757, 84890]
# 4                         [93737, 22987, 22988, 94534]
# ..                                                 ...
# 995  [24224, 87330, 26180, 22759, 86573, 23950, 861...
# 996  [88450, 85125, 22277, 84616, 22156, 24462, 245...
# 997                       [26449, 84853, 25854, 22759]
# 998                                     [22759, 22447]
# 999                                     [25522, 88486]
#
#                                       related_proteins          relation  \
# 0                                          [1641, 150]        indication
# 1    [3552, 417, 8834, 5667, 4968, 2889, 7083, 1004...        indication
# 2    [3104, 2401, 2789, 3046, 1884, 22023, 5320, 10...        indication
# 3    [2, 9221, 1549, 4111, 13840, 4114, 1558, 1559,...        indication
# 4         [2978, 9029, 4425, 12842, 1740, 12766, 4959]        indication
# ..                                                 ...               ...
# 995  [12165, 33925, 33926, 10376, 33929, 2698, 3405...  contraindication
# 996                                      [9905, 10181]  contraindication
# 997                                  [5203, 341, 9207]  contraindication
# 998  [8192, 10257, 22, 6175, 33, 2082, 2096, 6195, ...  contraindication
# 999                              [13976, 22077, 13230]               NaN
#
#      display_relation  x_index  y_index
# 0          indication  14520.0  33651.0
# 1          indication  15098.0  33683.0
# 2          indication  15493.0  29637.0
# 3          indication  14275.0  30654.0
# 4          indication  20375.0  33714.0
# ..                ...      ...      ...
# 995  contraindication  14168.0  31493.0
# 996  contraindication  20427.0  31918.0
# 997  contraindication  20350.0  30491.0
# 998  contraindication  15776.0  27933.0
# 999               NaN      NaN      NaN
#
# [1000 rows x 12 columns]

# %%
test_data_sub = test_data[['disease_index', 'drug_index']].drop_duplicates()
train_data_sub = train_data[['disease_index', 'drug_index']].drop_duplicates()

# %%
overlap = test_data_sub.merge(train_data_sub, on=['disease_index', 'drug_index'], how='inner')
if not overlap.empty:
    print("There is overlap:")
    print(overlap)
else:
    print("No overlap found.")
# Out:
# No overlap found.

# %%
indication_relation = "indication"

indication_edges = df_edges[df_edges['relation'] == indication_relation][['x_index', 'y_index']]
print(indication_edges)

contraindication_relation = "contraindication"

contraindication_edges = df_edges[df_edges['relation'] == contraindication_relation][['x_index', 'y_index']]
print(contraindication_edges)

# %%
combined_sub = pd.concat([test_data_sub, train_data_sub]).drop_duplicates()

combined_sub = combined_sub.rename(columns={'disease_index': 'a', 'drug_index': 'b'})


pairs_to_remove = set([tuple(x) for x in combined_sub[['a', 'b']].values])
pairs_to_remove |= set([tuple(x[::-1]) for x in combined_sub[['a', 'b']].values])  

indication_edges_filtered = indication_edges[
    ~indication_edges[['x_index', 'y_index']].apply(tuple, axis=1).isin(pairs_to_remove)
]

print(indication_edges_filtered)
# Out:
#          x_index  y_index
# 346730     16687    33577
# 346731     16687    36035
# 346764     20297    33577
# 346765     20297    36035
# 346768     16693    33577
# ...          ...      ...
# 5776153    84333    14471
# 5776154    27527    16634
# 5776155    38622    16634
# 5776156    28673    16634
# 5776158    39497    17237
#
# [16222 rows x 2 columns]

# %% [markdown]
# drug: Fosinopril disease: hypertensive disorder
#
#
# drug: Rotigotine disease: hypertensive disorder

# %%
contraindication_edges_filtered = contraindication_edges[
    ~contraindication_edges[['x_index', 'y_index']].apply(tuple, axis=1).isin(pairs_to_remove)
]

print(contraindication_edges_filtered)
# Out:
#          x_index  y_index
# 346728     15193    33577
# 346729     15193    36035
# 346732     14483    33577
# 346733     14483    36035
# 346734     16476    33577
# ...          ...      ...
# 5776145    35751    14251
# 5776146    35846    20456
# 5776147    35751    20456
# 5776148    27446    17286
# 5776157    84334    18277
#
# [58450 rows x 2 columns]
